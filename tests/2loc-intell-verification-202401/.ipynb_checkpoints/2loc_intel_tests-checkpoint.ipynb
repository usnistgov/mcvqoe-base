# %% [markdown]
# # Two location intelligibility verification
#
# This notebook is designed to use an exisiting set of 2 location transmit data (Harvard phrases and IRBIG-B time signals) to create a receieve dataset with known channel conditions. The script will create a rx dataset with either insert clean audio or only the first half of the phrase. The first half of the phrase does not contain the key word, so expected intelligibility should be zero, but fitting and aligning algorithms for m2e estimates will probably still work. It creates parallel directories, each representing a single rx dataset. Each parallel directory has a different error rate. The script also varies the record delay (simulating a m2e latency). The script uses either no delay (0 m2e latency), or the longest delay possible with a given irigb audio channel (usually about 1s m2e).
#
# Each rx dataset is then intelligibility scored.

# %% [markdown]
# ## 2 location script
#
# Below is the two location scoring function that this notebook validates

# %%
## 2loc script

## helper functions (need to go into 2loc processing script)

#TODO test_name_parts needs updating with new conventions
import csv, glob, json, math, os, re, shutil 
from datetime import datetime, timedelta
import numpy as np

import abcmrt #TODO v2 add to big script


import mcvqoe
from mcvqoe.base.terminal_user import terminal_progress_update
from mcvqoe.timing.audio_chans import timecode_chans
from mcvqoe.timing.timecode import time_decode
from mcvqoe.utilities.reprocess import get_module, reprocess_file
from mcvqoe.delay import ITS_delay_est, sliding_delay_estimates

def test_name_parts(name):
    m=re.match( r'(?P<prefix>.*capture)_'+
                    '(?P<testtype>.+)_'+
                    '(?P<date>\d{2}-\w{3}-\d{4}_\d{2}-\d{2}-\d{2})'+
                    '(?P<ext>\.\w+)?$',
                name
              )
    if not m:
        raise RuntimeError(f'Unable to find test name parts from \'{name}\'')
    return (m.group('prefix'),m.group('testtype'),m.group('date'))

def timedelta_total_seconds(time):
    try:
        #try it as if it's an array
        return [timedelta_total_seconds(t) for t in time]
    except TypeError:
        #not an array, must be scalar time
        return time.days*(24*60*60) + time.seconds + time.microseconds*1e-6

#function to quickly find the index of the nearest value
#from https://stackoverflow.com/a/26026189
def find_nearest(array,value):
    idx = np.searchsorted(array, value, side="left")
    if idx > 0 and (idx == len(array) or math.fabs(value - array[idx-1]) < math.fabs(value - array[idx])):
        return idx-1
    else:
        return idx

# two location processing function

def twoloc_process(test_type, tx_name, extra_play=0, rx_name = None, outdir="",
                        progress_update=terminal_progress_update,
                        align_mode='fit',
                        **kwargs       #get kwargs to accept arbitrary arguments
                   ):
    diagnostic_counter = 1000 ### number of rows to run before breaking TODO: remove
    '''
    Process rx and tx files for a two location test.
    
    This writes a .csv file to data/csv and wave files to data/wav for a test. 

    Parameters
    ----------
    test_type : string
        'm2e' or 'intelligibility'
    tx_name : string
        path to the transmit .csv file. If this is a relative path than
        `[outdir]/data/csv` is searched.
    extra_play : float, default=0
        Extra audio to add after tx clip stopped. This mayb be used, in some
        cases, to correct for data that was recorded with a poorly chosen
        overplay.
    rx_name : string, None
        Name of the receive .wav file. If this is a relative path than
        `[outdir]/data/csv` is searched. If this is None then `data/2loc_rx-data`
        is searched.
    outdir : string, default=""
        Directory that contains the `data/` folder where data will be read from
        and written to.
    progress_update : function, default=terminal_user
        Function to call with updates on processing progress. 
        
    See Also
    --------
        mcvqoe.mouth2ear : mouth to ear code, can produce 2 location data.
    '''


    #TODO: 'Validate inputs' needs updating with new conventions

    #-----------------------------Validate inputs-----------------------------

    #determine test type 
    if test_type not in ('m2e', 'intelligibility'):
            raise RuntimeError(f"'test_type' argument must be 'm2e' or 'intelligibility' not {test_type}")

    #normalize path
    tx_name = os.path.normpath(tx_name)

    if os.path.isdir(tx_name):
        #given directory, assume this is the .wav dir
        tx_wav_path = tx_name
        #find .csv files in the directory
        csvs = glob.glob(os.path.join(tx_wav_path, '*.csv'))

        if not csvs:
            raise RuntimeError(f'No .csv files found in \'{tx_wav_path}\'')
        elif len(csvs) > 1:
            raise RuntimeError(f'More than one .csv file found in \'{tx_wav_path}\'')

        tx_name = csvs[0]
    else:
        #get folder path from filename
        tx_wav_path=os.path.dirname(tx_name)

    #get folder name (just name, no path)
    tx_wav_fold =  os.path.basename(tx_wav_path)

    if not tx_wav_fold:
        raise RuntimeError(f'unable to extract wav folder from \'{tx_name}\'')

    #extract parts of tx name for validation
    (tx_prefix,tx_tt,tx_date)=test_name_parts(tx_wav_fold)
    #check prefix
    if(tx_prefix != 'Tx_capture'):
        raise ValueError(f'Unexpected filename prefix \'{tx_prefix}\' for tx file')
    
    #extra_play must be non-neg
    if extra_play < 0:
        raise ValueError("extra_play must be non negative")

    #tolerance for timecode variation
    tc_warn_tol = 0.0001

    
    #TODO: 'Locate input data' needs updating with new conventions
    # --------------------------[Locate input data]--------------------------
    
    #go two levels up from .csv file
    tx_fold=os.path.dirname(os.path.dirname(tx_name))
    
    indir=os.path.abspath(os.path.join(tx_fold,'..','..'))
    
    #check if rx_name is a directory
    if rx_name and os.path.isdir(rx_name):
        #use rx_name as dir
        rx_dir = rx_name
        #we don't have a specific name, clear rx_name
        rx_name = None
    else:
        rx_dir=os.path.join(indir,'data','2loc_rx-data')

    #TODO: 'Setup Files and folders' may need to be reconfigured to have it make more sense with new conventions
    # -----------------------[Setup Files and folders]-----------------------

    # generate data dir names
    data_dir = os.path.join(outdir, "data")
    wav_data_dir = os.path.join(data_dir, "wav")
    csv_data_dir = os.path.join(data_dir, "csv")

    # create data directories
    os.makedirs(csv_data_dir, exist_ok=True)
    os.makedirs(wav_data_dir, exist_ok=True)

    # generate base file name to use for all files
    base_filename ='_'.join(('capture2',tx_tt,tx_date))

    # generate test dir names
    wavdir = os.path.join(wav_data_dir, base_filename)

    # create test dir
    os.makedirs(wavdir, exist_ok=True)

    # generate csv name
    csv_out_name = os.path.join(csv_data_dir, f"{base_filename}.csv")
    print(csv_out_name)
    
    #------------------Find appropriate rx file by timecode------------------
    #if a rx file name is not specified, find the appropriate file in rx-dat 
    #folder. if there are more than one suitable rx files based on timecode, 
    #this will find the one with the smallest delay, with delay defined as 
    #difference between the start times of the rx and tx recordings
    
    #if no file was specified for the rx file, search for it in rx-dat
    if not rx_name:
    
        #attempt to get date from tx filename
        print(f'The tx date is {tx_date}')
        tx_date=datetime.strptime(tx_date, '%d-%b-%Y_%H-%M-%S')
        
        #rx_files is a dict with the delays as keys, and the rx path as values
        rx_files = {}
        progress_update('status', 0, 0, msg=f'looking for rx files in \'{rx_dir}\'')
        #loop thru all rx 
        
        for rx_file_name in glob.glob(os.path.join(rx_dir,'*.wav')):
            progress_update('status', 0, 0, msg=f'Looking at {rx_file_name}')
            #strip leading folders
            rx_basename=os.path.basename(rx_file_name)
            #split into parts
            (rx_prefix,rx_tt,rx_date)=test_name_parts(rx_basename)
            #validate that this is a correct rx file
            if rx_prefix != 'Rx_capture':
                #give error
                progress_update('warning', 0, 0, msg=f'Rx filename "{rx_basename}" is not in the proper form. Can not determine Rx filename')
                #if not a correct rx file, skip this file and go to next one
                continue
            rx_start_date=datetime.strptime(rx_date, '%d-%b-%Y_%H-%M-%S')
            #add to the rx_file dict, with delays as the key, and full path as value
            rx_files[tx_date - rx_start_date] = rx_file_name
    
        #create a np array of all of delays
        delays = np.array(list(rx_files), dtype=timedelta)
        
        #find the smallest positive delay
        minDelay = min(delays[delays > timedelta()])
        
        #find the file with the the smallest delay
        rx_name=rx_files[minDelay]

        progress_update('status', 0, 0, msg=f'Loading {rx_name}')

        #read file
        rx_fs, rx_dat = v
    
        #find the duration of the rx file
        duration = timedelta(seconds=len(rx_dat)/rx_fs)
        
        print(duration)
        
        #check that tx date falls within rx file time
        if minDelay < duration:
            rx_name = rx_files[minDelay]
        #otherwise there is no suitable rx file
        else:
            raise ValueError("Could not find suitable Rx file")
    
    else:
        rx_fs, rx_dat = mcvqoe.base.audio_read(rx_name)
    
    rx_dat=mcvqoe.base.audio_float(rx_dat)

    #+gsh3 for mrt, check fs
    if test_type == 'intelligibility':
        if(abcmrt.fs != rx_fs):
               raise RuntimeError('Recorded intelligibility sample rate does not match abcmrt!')

    
    #--------------------Prep work for calculating delays--------------------

    #data placeholders
    rx_info_name= os.path.splitext(rx_name)[0]+'.json'
    rx_align_rec= os.path.splitext(rx_name)[0]+'_align_rec.wav' #+gsh3 for diagnostic output
    
    with open(rx_info_name) as info_f:
        rx_info=json.load(info_f)

    #find timecode channel
    tc_chans=timecode_chans(rx_info['channels'])
    if not tc_chans:
        raise ValueError(f'Timecode channel could not be found in {rx_info["channels"]}')
    
    #use the first one
    rx_tc_idx=tc_chans[0]
    
    #timecode type
    rx_tc_type=rx_info['channels'][rx_tc_idx]
    
    #get channels
    rx_extra_chans=rx_info['channels']
    #remove timecode channel
    del rx_extra_chans[rx_tc_idx]
    
    #decode the rx timecode
    rx_tca = rx_dat[:,rx_tc_idx]
    rx_time, rx_snum = time_decode(rx_tc_type,rx_tca, rx_fs)
    
    
    ###### This block outputs for diagnostic purposes gsh3#######
    # def time_formatter(dt_s):
    #     days = []
    #     seconds = []
    #     for dt in dt_s:
    #         day = f"{dt.year}_{dt.month}_{dt.day}"  
    #         days.append(day)
    #         second = dt.hour*60*60 + dt.minute*60 + dt.second
    #         seconds.append(second)
    #     days = set(days)
    #     return days, seconds
        
    # days, seconds = time_formatter(rx_time) #
    
    # rx_dict = {'rx_date': list(days), 
    #            'rx_times': seconds,  # +gsh3
    #            'rx_snum': rx_snum.tolist()           # +gsh3
    #           } 
    # rx_time_name= os.path.splitext(rx_name)[0]+'_time.json'     
    # output_json = json.dumps(rx_dict)        # +gsh3            
    # with open(rx_time_name, 'w') as output:  # +gsh3            
    #     output.write(output_json)            # +gsh3            
   ##############################################################
    
    #make rx_time a numpy array
    rx_time = np.array(rx_time)
    
    if align_mode == 'interpolate':
        #we are interpolating, get reference time
        ref_time =  rx_time[0]
        #interpolate so we have intermediate values
        rx_interp = np.interp(range(len(rx_dat)),rx_snum,timedelta_total_seconds(rx_time-ref_time))
    elif align_mode == 'fit':
        #we are fitting, get reference time
        ref_time =  rx_time[0]
        #fit index vs time
        #do a linear fit of the timecode data to get time vs index
        rx_fit = np.polyfit(timedelta_total_seconds(rx_time-ref_time), rx_snum, 1)
        #get model
        rx_idx_fun = np.poly1d(rx_fit)

    extra_samples = extra_play * rx_fs

    ### iterate through the TX CSV rows to find the timing code and align with the RX codes
    with open(tx_name,'rt') as tx_csv_f, open(csv_out_name,'wt',newline='') as out_csv_f:

        #create dict reader
        reader=csv.DictReader(tx_csv_f)
        header = reader.fieldnames

        if test_type == 'intelligibility':
            header.append('m2e_latency')

        else: 
            header.append('Intelligibility')
        
        #create dict writer, same fields as input
        writer=csv.DictWriter(out_csv_f,header)
        writer.writeheader()
        
        #get data from file
        #NOTE : this may not work well for large files! but should, typically, be fine
        rows = tuple(reader)
        
        #get total trials for progress
        total_trials = len(rows)
    
        #loop through all tx recordings
        counter = 0
        for trial,row in enumerate(rows):
            counter += 1
            if counter > diagnostic_counter:
                break #= 10 ### number of rows to run before breaking TODO: remove
            
            progress_update('proc', total_trials, trial)
            
            tx_rec_name = f'Rx{trial+1}_{row["Filename"]}.wav'
            full_tx_rec_name = os.path.join(tx_wav_path, tx_rec_name)

            #check if file exists
            # if not os.path.exists(clip_path): gsh3
            if not os.path.exists(full_tx_rec_name): #+gsh3
                #update progress
                progress_update('status', total_trials, trial,
                msg = f"{full_tx_rec_name} not found")
                #unzip audio if it exists
                # mcvqoe.base.Measure.unzip_audio(audio_path) #-gsh3

            tx_rec_fs, tx_rec_dat = mcvqoe.base.audio_read(full_tx_rec_name)

            #check that audio sampling rate is the same  +gsh3
            if rx_fs != tx_rec_fs:
                 raise ValueError(f'RX and TX sampling not the same for {tx_wav_path}')

            #make floating point for processing purposes
            tx_rec_dat=mcvqoe.base.audio_float(tx_rec_dat)
            
            tx_rec_chans=mcvqoe.base.parse_audio_channels(row['channels'])
            
            if(len(tx_rec_chans)==1):
                #only one channel, make sure that it's a timecode
                if('timecode' not in tx_rec_chans[0]):
                    raise ValueError(f'Expected timecode channel but got {row["channels"][0]}')
                
                #make sure that timecode types match
                if rx_tc_type != tx_rec_chans[0]:
                    raise ValueError(f'Tx timecode type is {tx_rec_chans[0]} but Rx timecode type is {rx_tc_type}')
                
                #one channel, only timecode
                tx_rec_tca=tx_rec_dat
                
                tx_extra_audio = None
                tx_extra_chans = None
            else:                
                #grab the same type of timecode we used for Rx
                tx_time_idx = tx_rec_chans.index(rx_tc_type)

                tx_rec_tca = tx_rec_dat[:,tx_time_idx]

                #extra channels
                tx_extra_audio = np.delete(tx_rec_dat,tx_time_idx,1)

                #copy to new array without timecode channel
                tx_extra_chans = list(tx_rec_chans)
                del tx_extra_chans[tx_time_idx]
            
            #decode TX timecode
            tx_time, tx_snum = time_decode(rx_tc_type, tx_rec_tca, tx_rec_fs)
            
            try: ### 
                # check if it's fitting more than one IRIGB point
                if len(tx_time) == 1: 
                    one_point_fit = True
                    
                if align_mode == 'fixed':
                    #TODO: intelligibility only works with fixed align_mode
                    #array for matching sample numbers
                    tx_match_samples = []
                    rx_match_samples = []
    
                    for time,snum in zip(tx_time,tx_snum):
                        
                        #calculate difference from rx timecode
                        time_diff = abs(rx_time - time)
                        
                        #find minimum difference
                        min_v = np.amin(time_diff)
    
                        #check that difference is small
                        if min_v < timedelta(seconds=0.5):
    
                            #get matching index
                            idx=np.argmin(time_diff)
    
                            #append sample number
                            tx_match_samples.append(snum)
                            rx_match_samples.append(rx_snum[idx])
    
                    #get matching frame start indicies
                    mfr=np.column_stack((tx_match_samples, rx_match_samples))
    
                    #get difference between matching timecodes
                    mfd=np.diff(mfr, axis=0)
    
                    #get ratio of samples between matches
                    mfdr = mfd[:,0] / mfd[:,1]
    
                
                    if not np.all(np.logical_and(mfdr < (1+tc_warn_tol), mfdr>(1-tc_warn_tol))):
                        progress_update('warning', total_trials, trial, f'Timecodes out of tolerence for trial {trial+1}. {mfdr}')
    
                    #calculate first rx sample to use
                    first=mfr[0,1]-mfr[0,0]
    
                    #calculate last rx sample to use
                    last=mfr[-1,1]+len(tx_rec_tca)-mfr[-1,0]+extra_samples - 1
                
                elif align_mode == 'interpolate' or align_mode =='fit':
                    tx_tnum =timedelta_total_seconds(tx_time - ref_time)
    
                    #do a linear fit of the timecode data to get index vs time
                    fit = np.polyfit(tx_snum, tx_tnum, 1)
                    #get model
                    tc_fun = np.poly1d(fit)
    
                    #get time of start and end of tx clip
                    tx_start_time = tc_fun(0)
                    tx_end_time = tc_fun(len(tx_rec_tca) + extra_samples - 1)
    
                    if align_mode == 'interpolate':
                        #get indices in the Rx array
                        first = find_nearest(rx_interp, tx_start_time)
                        last  = find_nearest(rx_interp, tx_end_time)
                    elif align_mode == 'fit':
                        first = math.floor(rx_idx_fun(tx_start_time))
                        last  = math.ceil(rx_idx_fun(tx_end_time))
    
                else:
                    raise ValueError(f'Invalid value, \'{align_mode}\' for align_mode')
                #get rx recording data from big array
                rx_rec=rx_dat[first:last+1,:]
                #remove timecode
                rx_rec = np.delete(rx_rec,rx_tc_idx,1)
                #diagnostic output gsh3
                # mcvqoe.base.audio_write(rx_align_rec, 48000, rx_rec)
            
            
                if tx_extra_chans:
                    #add tx extra chans to rx extra chans
                    out_chans=tuple(rx_extra_chans+tx_extra_chans)
    
                    #get the length of the longest array
                    new_len = np.max((rx_rec.shape[0],tx_extra_audio.shape[0]))
    
                    #resize recording
                    rec_shape = list(rx_rec.shape)
                    rec_shape[0] = new_len
                    rx_rec.resize( tuple(rec_shape))
    
                    #resize tx extra
                    tx_shape = list(tx_extra_audio.shape)
                    tx_shape[0] = new_len
                    tx_extra_audio.resize( tuple(tx_shape))
    
                    #both arrays should now be the same length (in time)
                    out_audio=np.column_stack((rx_rec,tx_extra_audio))
                else:
                    #no extra chans, all out chans from rx
                    out_chans=rx_extra_chans
                    out_audio=rx_rec
            
                #overwrite new channels to csv
                row['channels']=mcvqoe.base.audio_channels_to_string(out_chans)
            
                ## find the phrase file if only the timing is present
                if tx_extra_audio is None:
                    full_tx_phrase_name = os.path.join(tx_wav_path, 'Tx_' + row['Filename'] + '.wav')
                    if not os.path.exists(full_tx_phrase_name):
                        raise ValueError(f'cannot find {full_tx_phrase_name}')
                    
                    tx_phrase_fs, tx_phrase_dat = mcvqoe.base.audio_read(full_tx_phrase_name)
                    if tx_phrase_fs != rx_fs:
                        raise ValueError(f'RX and TX sampling not the same for {full_tx_phrase_name}')
                    tx_extra_chans = mcvqoe.base.audio_float(tx_phrase_dat)
                
                rx_phrase = np.concatenate(rx_rec)


                 ########## m2e calculation  ########################################
                (pos, delay_points) = ITS_delay_est(tx_extra_chans, 
                                                    rx_phrase, 
                                                    'f', 
                                                    fs=rx_fs, 
                                                    dlyBounds=[np.NINF, np.inf], 
                                                    min_corr=0)
    
                delay_time = delay_points/tx_phrase_fs
                
                row['m2e_latency'] = delay_time 

            
                ########## intelligibility calculation  ##############################
                if test_type == 'intelligibility':
                    try:
                        ### latency estimate to adjust time capture
                        first     = first + delay_points*3//2
                        last      = last + delay_points*3//2
                        rx_rec    = rx_dat[first:last+1,:]
                        rx_rec = np.delete(rx_rec,rx_tc_idx,1)
                        rx_phrase = np.concatenate(rx_rec)
                         
                        word_num=abcmrt.file2number(full_tx_rec_name)  ### TX FILE NAME GOES HERE
                    except:
                        raise ValueError(f'cannot inturrpert {full_tx_rec_name} as an abcmrt phrase number')
    
                    phi_hat, intelligibility=abcmrt.process(rx_phrase, word_num) ##RX VOICE AUDIO GOES HERE
                    row['Intelligibility'] = intelligibility[0] #only a single list element
                a = 0
            except:
                # raise 
                print(f'failed to align {row}')  ## for testing TODO remove
                pass
                    ##################################
           
            
            # Create audiofile name/path for recording
            audioname = f'Rx{trial+1}_{row["Filename"]}.wav'
            audioname = os.path.join(wavdir, audioname)

            
            #save out Rx recording as given data type
            mcvqoe.base.audio_write(audioname,rx_fs,out_audio)
                
            #write row to new .csv
            writer.writerow(row)
        
        #copy Tx files into destination folder
        for name in glob.glob(os.path.join(tx_wav_path,'Tx_*')):
            #get clip name from path
            clip_name=os.path.basename(name)
            #construct destination name
            destname=os.path.join(wavdir,clip_name)
            #copy file
            shutil.copyfile(name,destname)

    #return output filename
    return csv_out_name

# %% [markdown]
# ## Simulate the data

# %%
import os, shutil
import pandas as pd
import numpy as np
from mcvqoe.base import audio_write
from mcvqoe.base import audio_read

import warnings
warnings.filterwarnings('ignore')
from IPython.display import clear_output

#directory containing audio tx phrases, irib-b audio, and 2loc csv 
tx_dir = '/Users/gsh3/Documents/working/mcv/2loc/intel/2loc-intell-verification-202401/Tx_capture_Intell_18-Jan-2024_15-19-04' 

#directory where new rx data directories will be created
rx_dir = '/Users/gsh3/working/mcv/2loc/intel/2loc-intell-verification-202401/'

# %%
## use the previous trial to build the list of tx files
csv_name = os.path.basename(tx_dir)[3:] + '.csv'   #find csv name
csv_path = os.path.join(tx_dir, csv_name)          #set csv path
irig_files = [x for x in os.listdir(tx_dir) if 'Rx' in x]
phrase_files = [x for x in os.listdir(tx_dir) if 'Tx' in x]
df = pd.read_csv(csv_path)
df.head
# Out:
# <bound method NDFrame.head of                Timestamp        Filename          channels  Intelligibility
# 0   18-Jan-2024 15:19:06  F3_b35_w1_orig  (IRIGB_timecode)              NaN
# 1   18-Jan-2024 15:19:14  M3_b10_w4_orig  (IRIGB_timecode)              NaN
# 2   18-Jan-2024 15:19:22  F1_b44_w3_orig  (IRIGB_timecode)              NaN
# 3   18-Jan-2024 15:19:29   F3_b8_w1_orig  (IRIGB_timecode)              NaN
# 4   18-Jan-2024 15:19:38  F1_b39_w2_orig  (IRIGB_timecode)              NaN
# ..                   ...             ...               ...              ...
# 59  18-Jan-2024 15:26:49  F3_b11_w4_orig  (IRIGB_timecode)              NaN
# 60  18-Jan-2024 15:26:57  M3_b32_w1_orig  (IRIGB_timecode)              NaN
# 61  18-Jan-2024 15:27:05  F1_b40_w5_orig  (IRIGB_timecode)              NaN
# 62  18-Jan-2024 15:27:13  M4_b25_w1_orig  (IRIGB_timecode)              NaN
# 63  18-Jan-2024 15:27:21  F3_b29_w2_orig  (IRIGB_timecode)              NaN
#
# [64 rows x 4 columns]>

# %%
# make lists of the target files in order
irig_paths = []
phrase_paths = []
for filename in df.Filename: 
    irig_file = [x for x in irig_files if filename in x][0]  #find irig file target name
    irig_paths.append(os.path.join(tx_dir, irig_file))
    
    phrase_file = [x for x in phrase_files if filename in x][0]  #find irig file target name
    phrase_paths.append(os.path.join(tx_dir, phrase_file))

# %%
str(1/100000)
# Out:
# '1e-05'

# %%
#### create and intelligibility score new rx data 

score_dfs = [] # used to aggreate the score1
counter = 0
error_rates = np.linspace(0, 1 , 11) #error rates
fraction_list = [0.5, 0.25, 0] #audio fractions to keep at front (1 being all, 0 being none, don't use 0 (divde error))
for fraction in fraction_list: #fraction of audio played for errorful data 
    for delay_status in [True, False]: # whether or not to add a simulated m2e delay
        for rate in error_rates:# liklihood of silent audio per trial
    
            delay = delay_status
            error_rate = np.round(rate, 2) # liklihood of total failure , round avoids weird float-point errors
            
            #### setup the dir structure for rx data #### 
    
            # appends delay status to dir name
            if delay:
                ds = 'd'
            else:
                ds = 'nd'

            out      = f'{error_rate}_{ds}_{fraction}'
            out_dir  = os.path.join(rx_dir, f'err_{out}')
            # out_dir = f'/Users/gsh3/working/mcv/2loc/intel/2loc-intell-verification-202401/err_{error_rate}/' #TODO
            out_name = f'rx_{out}_simulation_{os.path.basename(tx_dir)}'
            #overwrite exisiting directories if they exist
            if os.path.exists(out_dir):
                shutil.rmtree(out_dir)
            os.mkdir(out_dir)
            os.chdir(out_dir)
            
            # #add in standard JSON to keep 2loc script happy
    
            
            # write the standard json data to rx directory, 2loc script requires it
            json_data = {'channels': ['rx_voice', 'IRIGB_timecode']}
            json_object = json.dumps(json_data, indent=4)
            with open(os.path.join(out_dir, out_name+'.json'), "w") as outfile:
                outfile.write(json_object)        # shutil.copyfile('/Users/gsh3/Documents/working/mcv/2loc/intel/2loc-intell-verification-202401/rx_clean_simulation_Tx_capture_Intell_18-Jan-2024_15-19-04.json', 
            #                 os.path.join(out_dir,out_name+'.json'))
            
            # empty array to hold the data
            two_channel = np.array([], dtype=np.float64).reshape(0,2)
            
            #which phrases will fail and write them 
            error_list = np.random.choice([True, False], size=len(phrase_paths), p = [1-error_rate, error_rate])
            error_df  = pd.DataFrame(error_list, columns=['error_state'])
            error_df['error_rate'] = error_rate 
            error_df.to_csv('error_list.csv')
            
            ###### loop through phrases and time signals to create rx dataset #######
            for i, p, e in zip(irig_paths, phrase_paths, error_list):
            
                #read the audio data 
                sr, irig_dat = audio_read(i)
                _, phrase_dat = audio_read(p)
            
                #single channel audio phrase 
                if e: # good data
                    if delay:  # zero-fill before phrase
                        new = np.concatenate([np.zeros(irig_dat.shape[0] - phrase_dat.shape[0]),
                                                       phrase_dat])
                    
                    else: # zero-fill after phrase
                        new = np.concatenate([phrase_dat, 
                                          np.zeros(irig_dat.shape[0] - phrase_dat.shape[0])])      
                
                else: #first audio fraction
                    part_phrase = phrase_dat[:int(len(phrase_dat)*fraction)] 
                    if delay: #zeros first to simulate delay
                        new = np.concatenate([np.zeros(irig_dat.shape[0] - part_phrase.shape[0]),
                                             part_phrase])
                    else: #zeros after 
                        new = np.concatenate([part_phrase, 
                                              np.zeros(irig_dat.shape[0] - part_phrase.shape[0])])      
                    
                #combine audio channels
                two_channel = np.concatenate([two_channel, 
                                                  np.array([new, irig_dat]).transpose()])
            # write the simulated rx audio 
            wave_path = os.path.join(out_dir, out_name+'.wav')
            audio_write(wave_path, 48000, two_channel)
            
            ######  call the two loc function.   
            for align in ['fit', 'fixed']: # try both working align modes
                counter += 1
                total_conditions = 2*2*len(error_rates)*len(fraction_list) # assumes delay on/off, fixed/fit,
                os.mkdir(os.path.join(out_dir, align)) # TODO change
                os.chdir(os.path.join(out_dir, align))
            
                print(f'Scoring condition {counter} of {total_conditions} \n', 
                      f'error rate: {error_rate}, m2e delay: {delay}, align mode: {align}.')
                
                csv_path = twoloc_process(test_type = 'intelligibility',
                               tx_name = tx_dir,
                               rx_name = wave_path,
                               align_mode = align, ) # only 'fit' and 'fixed' are working correct
            # read output csv into a df 
                score_df = pd.read_csv(csv_path)
                score_df['align_mode'] = align #append align state to data
                score_df['delay'] = delay #append delay state
                score_df['audio_fraction'] = fraction
                
                # remove saved output audio
                shutil.rmtree('./data/wav/') 
            
            #add the error state to the scores
                merge = pd.merge(score_df, error_df, left_index=True, right_index=True)
                score_dfs.append(merge)
                clear_output(wait=True)
                
            
print(f'Ran and scored {counter} conditions')
merged_df = pd.concat(score_dfs)
merged_df.to_csv('../merged.csv') # save the scored data here
# Out:
# Scoring condition 25 of 132
#  error rate: 0.1, m2e delay: False, align mode: fit.
# data/csv/capture2_Intell_18-Jan-2024_15-19-04.csv
# Processing test data
# Processing trial 0 of 64
# failed to align {'Timestamp': '18-Jan-2024 15:19:29', 'Filename': 'F3_b8_w1_orig', 'channels': '(IRIGB_timecode)', 'Intelligibility': 'nan', 'm2e_latency': None}
# failed to align {'Timestamp': '18-Jan-2024 15:19:53', 'Filename': 'M3_b24_w3_orig', 'channels': '(rx_voice)', 'Intelligibility': 'nan', 'm2e_latency': 158.67625}
# Processing trial 10 of 64

# %% [markdown]
# ##      Analyze scored data

# %%
import pandas as pd
# drop nan from the bad data point
# read data if necessary
merged_df = pd.read_csv('../merged.csv')

# merged_df_2 = pd.read_csv('../merged_random.csv') # 50% On off for all rows
# check what's NaN
merged_df[merged_df['Intelligibility'].isna()].groupby(['align_mode', 'Filename']).count()
# Out:
#                            Unnamed: 0  Timestamp  channels  Intelligibility  \
# align_mode Filename
# fit        F1_b19_w3_orig          15         15        15                0
#            F1_b2_w1_orig           57         57        57                0
#            F1_b2_w4_orig           17         17        17                0
#            F1_b39_w4_orig          49         49        49                0
#            F3_b8_w1_orig           66         66        66                0
#            M3_b15_w6_orig          38         38        38                0
#            M3_b16_w4_orig          48         48        48                0
#            M3_b24_w3_orig          55         55        55                0
#            M3_b40_w4_orig          51         51        51                0
#            M3_b43_w4_orig          34         34        34                0
#            M3_b44_w6_orig          52         52        52                0
#            M4_b46_w3_orig          48         48        48                0
# fixed      F3_b29_w2_orig           5          5         5                0
#            F3_b8_w1_orig           66         66        66                0
#
#                            m2e_latency  delay  audio_fraction  error_state  \
# align_mode Filename
# fit        F1_b19_w3_orig           15     15              15           15
#            F1_b2_w1_orig            57     57              57           57
#            F1_b2_w4_orig            17     17              17           17
#            F1_b39_w4_orig           49     49              49           49
#            F3_b8_w1_orig             0     66              66           66
#            M3_b15_w6_orig           38     38              38           38
#            M3_b16_w4_orig           48     48              48           48
#            M3_b24_w3_orig           55     55              55           55
#            M3_b40_w4_orig           51     51              51           51
#            M3_b43_w4_orig           34     34              34           34
#            M3_b44_w6_orig           52     52              52           52
#            M4_b46_w3_orig           48     48              48           48
# fixed      F3_b29_w2_orig            5      5               5            5
#            F3_b8_w1_orig             0     66              66           66
#
#                            error_rate
# align_mode Filename
# fit        F1_b19_w3_orig          15
#            F1_b2_w1_orig           57
#            F1_b2_w4_orig           17
#            F1_b39_w4_orig          49
#            F3_b8_w1_orig           66
#            M3_b15_w6_orig          38
#            M3_b16_w4_orig          48
#            M3_b24_w3_orig          55
#            M3_b40_w4_orig          51
#            M3_b43_w4_orig          34
#            M3_b44_w6_orig          52
#            M4_b46_w3_orig          48
# fixed      F3_b29_w2_orig           5
#            F3_b8_w1_orig           66

# %%
merged_df[(merged_df['Intelligibility'].isna()) & (merged_df['Filename'] == 'F3_b29_w2_orig')]
# Out:
#       Unnamed: 0             Timestamp        Filename    channels  \
# 639           63  18-Jan-2024 15:27:21  F3_b29_w2_orig  (rx_voice)
# 767           63  18-Jan-2024 15:27:21  F3_b29_w2_orig  (rx_voice)
# 1023          63  18-Jan-2024 15:27:21  F3_b29_w2_orig  (rx_voice)
# 1151          63  18-Jan-2024 15:27:21  F3_b29_w2_orig  (rx_voice)
# 1279          63  18-Jan-2024 15:27:21  F3_b29_w2_orig  (rx_voice)
# 1407          63  18-Jan-2024 15:27:21  F3_b29_w2_orig  (rx_voice)
#
#       Intelligibility  m2e_latency align_mode  delay  audio_fraction  \
# 639               NaN       1.8855      fixed   True             0.5
# 767               NaN       1.8855      fixed   True             0.5
# 1023              NaN       1.8855      fixed   True             0.5
# 1151              NaN       1.8855      fixed   True             0.5
# 1279              NaN       1.8855      fixed   True             0.5
# 1407              NaN       1.8855      fixed   True             0.5
#
#       error_state  error_rate
# 639         False         0.4
# 767         False         0.5
# 1023        False         0.7
# 1151        False         0.8
# 1279        False         0.9
# 1407        False         1.0

# %%
plt.title('Distribution of audio intelligibility')
sns.violinplot(x='error_state', y='Intelligibility', hue = 'align_mode', data = merged_df)
# Out:
# <Axes: title={'center': 'Distribution of audio intelligibility'}, xlabel='error_state', ylabel='Intelligibility'>

# %% [markdown]
# ### Bad intelligibility discussion
#
# The 'errror_state' variables referrs to if a given audio clip has silence insrted into ('False' condition) or if the clip is clean and complete ('True' condition).
#
# The location script represeents failures to computer intelligibility as 'NaN'. File 'F3_b8_w1_orig' always gives 'NaN', suggesting there is a problem with that TX file. 'Fixed' clip alignment only fails on that file, where as 'fit' alignment fails much of the time. Further, there is a high rate of false negatives using 'fit'. There are essentially no false negatives using 'fixed'.
#
# These observations justify using only 'fixed' for processing two location intelligibility. There are also some errors with 'F3_b29_w2_orig', but only in the 'delay' condition. That's because that file is the last recorded phrase and sum of it is cliped because of how I implement the delay script, so I think it's okay to ignore that problem.
#
# All further analysis will be performed on only 'fixed'

# %%
# drop all failed trials and 'fit' aligned data the bad file
merged_df.dropna(how='any', inplace=True)   #drop bad data
merged_df = merged_df[merged_df['align_mode'] == 'fixed'] #use only fixed anlysis data

# %% [markdown]
# ## Characterize quality of scored data

# %%
## calculate scores
# Make the intelligibility outcome binary, using a threshold

from sklearn import metrics
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# make intelligibility scores binary with a threshold for True.==
threshold = 0.99

def float_to_bool(x, threshold): 
    if x > threshold:
        return True
    else:
        return False

merged_df['Int_binary'] = merged_df['Intelligibility'].apply(lambda x: float_to_bool(x, threshold))

true = merged_df['error_state']# expected intelligibility (True/False for audio on/off)
obs = merged_df['Intelligibility']
obs_bin = merged_df['Int_binary']
fpr, tpr, _  = metrics.roc_curve(true, obs)
auc = np.round(metrics.roc_auc_score(true, obs),3) 
acc = np.round(metrics.accuracy_score(true, obs_bin),3)
precision = np.round(metrics.precision_score(true, obs_bin), 3)
recall = np.round(metrics.recall_score(true, obs_bin), 3)

plt.plot(fpr, tpr)
sns.scatterplot(x=fpr, y=tpr)
# sns.ji
plt.title(f' Two location intelligibility validation test \n ROC, AUC = {auc} \n accuracy = {acc} \n precision = {precision} \n recall = {recall}')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.savefig('2loc_intel_validation.png')

# %%
fig = plt.figure(figsize=(3,2))
sns.color_palette("rocket", as_cmap=True)
sns.histplot(x='Intelligibility', y=merged_df['error_state'].astype('str'), data=merged_df, bins=[10,2], cbar=True, stat='probability', cmap="mako_r")

# plt.hist2d(x='Intelligibility', y='error_state', data=merged_df, bins=[11,2])
#TODO BIN LABELS
plt.xlabel('Intelligibility Score')
plt.title('2D histogram of intelligibiliy and error state')
# Out:
# Text(0.5, 1.0, '2D histogram of intelligibiliy and error state')

# %% [markdown]
# ## Goodness discussion
# All of the model goodness metrics are above 99%, suggesting that the two location intelligibility code is operating as expected. That is to say more then 99% of the time, the code produces the expected result, so we can call this success. We do observe from the 2D histogram, that there are some false positives, that is cropped audio being detected as relatively high intelligibility. I investigate those anomolies below. But since overall performance is excellent, I except the two location scoring as performing as designed.

# %%
plt.hist(merged_df[merged_df['error_state'] == False]['Intelligibility'])
plt.title('Distribution of Intelligibility scores for half phrase audio')
plt.ylabel('count')
plt.xlabel('Intelligibility')
# Out:
# Text(0.5, 0, 'Intelligibility')

# %%
plt.title('Distribution of bad audio intelligibility by audio fraction')
sns.violinplot(x='audio_fraction', y='Intelligibility', data = merged_df[merged_df['error_state'] == False])
# Out:
# <Axes: title={'center': 'Distribution of bad audio intelligibility by audio fraction'}, xlabel='audio_fraction', ylabel='Intelligibility'>

# %%
merged_df[(merged_df['error_state'] == False) & (merged_df['Intelligibility'] > 0.8)].groupby(['audio_fraction' ,'Filename']).count()
# Out:
#                                Unnamed: 0  Timestamp  channels  \
# audio_fraction Filename
# 0.25           F1_b47_w3_orig           6          6         6
#                M3_b12_w4_orig           1          1         1
#                M3_b16_w4_orig           1          1         1
#                M3_b44_w6_orig           6          6         6
#                M3_b45_w6_orig           3          3         3
# 0.50           F1_b19_w3_orig           5          5         5
#                F1_b2_w1_orig            2          2         2
#                M3_b10_w4_orig           1          1         1
#                M3_b16_w4_orig           7          7         7
#                M3_b24_w3_orig           5          5         5
#                M3_b45_w6_orig           1          1         1
#                M4_b23_w6_orig           8          8         8
#                M4_b46_w4_orig           1          1         1
#
#                                Intelligibility  m2e_latency  align_mode  \
# audio_fraction Filename
# 0.25           F1_b47_w3_orig                6            6           6
#                M3_b12_w4_orig                1            1           1
#                M3_b16_w4_orig                1            1           1
#                M3_b44_w6_orig                6            6           6
#                M3_b45_w6_orig                3            3           3
# 0.50           F1_b19_w3_orig                5            5           5
#                F1_b2_w1_orig                 2            2           2
#                M3_b10_w4_orig                1            1           1
#                M3_b16_w4_orig                7            7           7
#                M3_b24_w3_orig                5            5           5
#                M3_b45_w6_orig                1            1           1
#                M4_b23_w6_orig                8            8           8
#                M4_b46_w4_orig                1            1           1
#
#                                delay  error_state  error_rate  Int_binary
# audio_fraction Filename
# 0.25           F1_b47_w3_orig      6            6           6           6
#                M3_b12_w4_orig      1            1           1           1
#                M3_b16_w4_orig      1            1           1           1
#                M3_b44_w6_orig      6            6           6           6
#                M3_b45_w6_orig      3            3           3           3
# 0.50           F1_b19_w3_orig      5            5           5           5
#                F1_b2_w1_orig       2            2           2           2
#                M3_b10_w4_orig      1            1           1           1
#                M3_b16_w4_orig      7            7           7           7
#                M3_b24_w3_orig      5            5           5           5
#                M3_b45_w6_orig      1            1           1           1
#                M4_b23_w6_orig      8            8           8           8
#                M4_b46_w4_orig      1            1           1           1

# %%
## False positive percent 


x = np.linspace(.1,1, 200)
y = np.array([len(merged_df[(merged_df['error_state'] == False) & (merged_df['Intelligibility'] > t)]) for t in x])
tn= len(merged_df[(merged_df['error_state'] == False)])

sns.lineplot(x=x,y=y/tn*100)
# plt.plot(x,y/tn*100)
# sns.lineplot(x=x,y=y/tn*100, hue='audio_fraction')
plt.ylabel('Fraction of false positives (percent)')
plt.xlabel('Intelligibility threshold for false positive')


for threshold in [0.1, 0.2, 0.5]:# intelligibility level above which we call a trial a false positive
     # true negatives
    fp = len(merged_df[(merged_df['error_state'] == False) & (merged_df['Intelligibility'] > threshold)]) #false positives
    print(f'At threshold = {threshold}, false positive to true negative ratio is {fp/tn *100 :.1f} %.')
# Out:
# At threshold = 0.1, false positive to true negative ratio is 26.6 %.
# At threshold = 0.2, false positive to true negative ratio is 18.0 %.
# At threshold = 0.5, false positive to true negative ratio is 6.8 %.

# %% [markdown]
# ## False positive discussion
#
# As one can see from the violin plot and the filtered dataframe above, a small subset of data give a false positive. That is the audio should be at least half silence yet has very high intelligibility. Listening to the actual receive audio, I can confirm they are in fact the expected level of silence, so the error is in the ABCMRT. The level of intelligibility is positively correlated with the amount of retained audio. So, all silence always produces low intelligibility. Only half silence produces far more false positives even though its missing the keyword.
